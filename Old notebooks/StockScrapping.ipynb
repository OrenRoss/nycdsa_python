# %%
import csv
import numpy as np
import math as ma
import pandas as pd

# %%
vg_chartz = pd.read_csv(r'vgchartz-7_7_2020.csv')

# %%
len(pd.unique(vg_chartz['publisher']))
# Out:
# 3261

# %%
vg_copy = vg_chartz.copy()

# %%
vg_chartz = vg_chartz[vg_chartz.console != 'Series']
vg_chartz = vg_chartz[vg_chartz.genre != 'Visual Novel']

# %%
vg_chartz.head
list(pd.unique(vg_chartz['publisher']))
vg_copy[vg_copy.console == 'Series']
# Out:
#        Unnamed: 0                                            img  \
# 0               3  /games/boxart/full_3351915AmericaFrontccc.jpg
# 1               4  /games/boxart/full_5741036AmericaFrontccc.jpg
# 2               5  /games/boxart/full_6662824AmericaFrontccc.png
# 4               7  /games/boxart/full_6800951AmericaFrontccc.jpg
# 16             19  /games/boxart/full_8886048AmericaFrontccc.jpg
# ...           ...                                            ...
# 54132       54978  /games/boxart/full_7404545AmericaFrontccc.jpg
# 54133       54979  /games/boxart/full_7398718AmericaFrontccc.png
# 54139       54985  /games/boxart/full_5242617AmericaFrontccc.jpg
# 54142       54988  /games/boxart/full_9421541AmericaFrontccc.jpg
# 54189       55035  /games/boxart/full_9984096AmericaFrontccc.jpg
#
#                                title console     genre  \
# 0                           Warriors  Series    Action
# 1                         God of War  Series    Action
# ...

# %%
vg_chartz.loc[vg_chartz.Console != 'Series',:]
vg_chartz.groupby('publisher')

# %%
vg_copy['Grand Theft Auto' in vg_copy['title']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-2b2cf82a554b> in <module>
# ...

# %%
vg_copy[vg_copy['title'].str.contains('Grand Theft Auto')]
# Out:
#        Unnamed: 0                                            img  \
# 3               6  /games/boxart/full_6510540AmericaFrontccc.jpg
# 5               8  /games/boxart/full_5563178AmericaFrontccc.jpg
# 6               9                   /games/boxart/3887656ccc.jpg
# 8              11                    /games/boxart/827563ccc.jpg
# 9              12  /games/boxart/full_9218923AmericaFrontccc.jpg
# ...           ...                                            ...
# 21156       21486                      /games/boxart/default.jpg
# 21157       21487                      /games/boxart/default.jpg
# 21158       21488                      /games/boxart/default.jpg
# 21159       21489                      /games/boxart/default.jpg
# 21160       21490                      /games/boxart/default.jpg
#
#                                title console   genre       publisher  \
# 3                 Grand Theft Auto V     PS3  Action  Rockstar Games
# ...

# %%
# grouping stuff

group = vg_copy.groupby(['genre'])
group.agg(['mean', 'std', 'count'])['critic_score']
# Out:
#                       mean       std  count
# genre
# Action            6.840234  1.575293   1024
# Action-Adventure  7.665657  1.239170     99
# Adventure         7.329188  1.455842    394
# Board Game        5.300000       NaN      1
# Education         7.500000       NaN      1
# Fighting          7.388415  1.383228    328
# MMO               7.810000  1.408269     10
# Misc              6.885799  1.517741    338
# Music             7.973077  0.961065     26
# Party             6.053333  0.981156     15
# Platform          7.308333  1.382760    564
# Puzzle            7.200000  1.245273    285
# Racing            7.089417  1.518927    463
# Role-Playing      7.463097  1.217558    859
# Sandbox           9.200000       NaN      1
# Shooter           7.293152  1.493041    847
# Simulation        6.926201  1.543184    229
# Sports            7.291424  1.470802    688
# Strategy          7.432432  1.386042    370
# Visual Novel      8.500000  0.707107      2

# %%
group.agg(['mean', 'std', 'count'])['total_sales']
# Out:
#                       mean       std  count
# genre
# Action            0.409260  1.048028   2880
# Action-Adventure  0.556816  1.202643    267
# Adventure         0.177714  0.396895   1920
# Board Game        0.110000  0.164621      3
# Education         0.090000       NaN      1
# Fighting          0.400277  0.610933    903
# MMO               0.370625  0.520452     32
# Misc              0.289230  0.588833   2039
# Music             0.352752  0.708438    149
# Party             0.199630  0.209606     27
# Platform          0.429487  0.721179    975
# Puzzle            0.182527  0.330504    728
# Racing            0.373142  0.641461   1445
# Role-Playing      0.301925  0.625452   1600
# Sandbox           1.890000       NaN      1
# Shooter           0.690804  1.576579   1517
# Simulation        0.269409  0.552120   1133
# Sports            0.466748  0.821958   2617
# Strategy          0.164167  0.339148    864
# Visual Novel      0.026514  0.026962    218
