# %%
import yfinance as yf
import csv
import numpy as np
import math as ma
import pandas as pd
import plotly.express as px
import datetime

# %% [markdown]
# https://pypi.org/project/yfinance/
# https://analyticsindiamag.com/hands-on-guide-to-using-yfinance-api-in-python/

# %% [markdown]
# This is just starting to play around with stock stuff.

# %%
ttwo = yf.Ticker("TTWO")

# %%
hist = ttwo.history(period="max")

# %%
hist
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 1997-04-15    3.666441    3.916425    3.416456    3.916425  1785600
# 1997-04-16    3.916425    4.166410    3.583112    3.708104   443700
# 1997-04-17    3.749768    4.083081    3.749768    3.833096   252150
# 1997-04-18    3.833096    3.999753    3.833096    3.999753   165900
# 1997-04-21    3.916425    3.999753    3.916425    3.999753    77400
# ...                ...         ...         ...         ...      ...
# 2021-07-19  169.940002  172.229996  166.610001  168.960007  2109700
# 2021-07-20  170.910004  171.100006  167.970001  170.020004   861600
# 2021-07-21  170.470001  171.570007  170.139999  170.899994   903400
# 2021-07-22  170.679993  171.589996  169.199997  171.279999   605600
# 2021-07-23  171.149994  171.324997  169.520004  169.610001   203835
#
#             Dividends  Stock Splits
# Date
# 1997-04-15        0.0           0.0
# 1997-04-16        0.0           0.0
# ...

# %%
df = df.reset_index()

# %%
import plotly.express as px

# df = px.data.stocks()
# df.reset_index(inplace=True)
fig = px.line(df, x="Date", y="Close")
fig.add_vline(x=datetime.datetime(2020,5,27).timestamp() * 1000, line_dash='dash', annotation_text="hahaha")
fig.add_vrect(x0=datetime.datetime(2010,5,27).timestamp() * 1000, x1=datetime.datetime(2013,5,27).timestamp() * 1000,line_dash='dash', annotation_text="hahaha")
fig.show()

# %%
test = yf.Ticker("3635.T")

# %%
hist = test.history(period="max")
hist
# Out:
#                    Open         High          Low        Close  Volume  \
# Date
# 2001-01-04   319.638947   328.715107   315.692781   319.638947   13291
# 2001-01-05   312.141211   319.638932   312.141211   315.298157   17409
# 2001-01-08   315.298157   315.298157   315.298157   315.298157       0
# 2001-01-09   327.136533   327.136533   309.773438   309.773438   18720
# 2001-01-10   309.773528   309.773528   286.096558   286.096558   29577
# ...                 ...          ...          ...          ...     ...
# 2021-07-15  5050.000000  5060.000000  4955.000000  4975.000000  182900
# 2021-07-16  4945.000000  5000.000000  4935.000000  4955.000000  152000
# 2021-07-19  4930.000000  4985.000000  4900.000000  4905.000000  195100
# 2021-07-20  4905.000000  4930.000000  4845.000000  4865.000000  193600
# 2021-07-21  4935.000000  5010.000000  4910.000000  4985.000000  224200
#
#             Dividends  Stock Splits
# Date
# 2001-01-04        0.0           0.0
# ...
