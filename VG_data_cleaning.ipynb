# %%
import csv
import numpy as np
import math as ma
import pandas as pd
import plotly.express as px

# %%
video_game_df = pd.read_csv(r'Data/vg_df.csv')
vg_comp_stock = pd.read_csv(r'Data/pubs_STOCKS.csv')

# %%
vg_df = video_game_df.copy()

# %%
vg_stk = vg_comp_stock.copy()

# %%
vg_df = vg_df[vg_df['critic_score'].notna()]

# %%
vg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12495 entries, 3 to 57940
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             12495 non-null  object
#  1   console           12495 non-null  object
#  2   genre_x           12495 non-null  object
#  3   publisher         12495 non-null  object
#  4   developer_x       12495 non-null  object
#  5   critic_score      12495 non-null  float64
#  6   total_sales       9026 non-null   float64
#  7   release_date_x    12457 non-null  object
#  8   NA_Sales          6923 non-null   float64
#  9   EU_Sales          6923 non-null   float64
#  10  JP_Sales          6923 non-null   float64
#  11  Other_Sales       6923 non-null   float64
#  12  Global_Sales      6923 non-null   float64
#  13  Critic_Count      6866 non-null   float64
#  14  User_Count        6923 non-null   float64
#  15  Rating            6851 non-null   object
#  16  number_players    1698 non-null   object
#  17  positive_critics  2959 non-null   float64
#  18  neutral_critics   2959 non-null   float64
#  19  negative_critics  2959 non-null   float64
#  20  positive_users    2959 non-null   float64
#  21  neutral_users     2959 non-null   float64
#  22  negative_users    2959 non-null   float64
#  23  user_score        9728 non-null   float64
#  24  Title             3490 non-null   object
#  25  Publisher         3490 non-null   object
#  26  Genre             3490 non-null   object
#  27  Platform          3490 non-null   object
#  28  Metascore         3490 non-null   float64
#  29  Avg_Userscore     3490 non-null   float64
#  30  No_Players        4550 non-null   object
# dtypes: float64(18), object(13)
# memory usage: 3.1+ MB

# %%
vg_df.loc[ : ,'user_score'] = pd.to_numeric(vg_df['user_score'], errors='coerce')

# %%
print(len(vg_df))
print(vg_df['total_sales'].isna().sum())
print(vg_df['critic_score'].isna().sum())
print(vg_df['user_score'].isna().sum())
print(vg_df['User_Count'].isna().sum())
# Out:
# 8970
# 0
# 0
# 1140
# 2079

# %%
vg_df = vg_df[vg_df['total_sales'].notna()]

# %%
vg_df
# Out:
#                                    title console       genre_x  \
# 3                     Grand Theft Auto V     PS3        Action
# 5                     Grand Theft Auto V     PS4        Action
# 6          Grand Theft Auto: San Andreas     PS2        Action
# 7             Uncharted 4: A Thief's End     PS4        Action
# 8            Grand Theft Auto: Vice City     PS2        Action
# ...                                  ...     ...           ...
# 57617                        Root Letter     PS4  Visual Novel
# 57618                  Steins;Gate Elite     PS4  Visual Novel
# 57641              428: Shibuya Scramble     PS4  Visual Novel
# 57671                        Chaos;Child     PS4  Visual Novel
# 57765  Zero Escape: Virtue's Last Reward     PSV  Visual Novel
#
#                             publisher        developer_x  critic_score  \
# 3                      Rockstar Games     Rockstar North          94.0
# 5                      Rockstar Games     Rockstar North          97.0
# 6                      Rockstar Games     Rockstar North          95.0
# 7      Sony Interactive Entertainment        Naughty Dog          92.0
# 8                      Rockstar Games     Rockstar North          96.0
# ...                               ...                ...           ...
# 57617                           PQube     Kadokawa Games          69.0
# 57618                  Spike Chunsoft          5pb. Inc.          86.0
# 57641                  Spike Chunsoft  Abstraction Games          85.0
# 57671                           PQube          5pb. Inc.          76.0
# 57765                     Aksys Games           ChunSoft          84.0
#
#        total_sales release_date_x  NA_Sales  EU_Sales  ...  neutral_users  \
# 3            20.32     2013-09-17      7.02      9.09  ...            NaN
# 5            19.39     2014-11-18      3.96      6.31  ...           71.0
# 6            20.81     2004-10-26      9.43      0.40  ...            NaN
# 7             5.38     2016-05-10      1.85      2.50  ...          148.0
# 8            16.15     2002-10-28      8.41      5.49  ...            NaN
# ...            ...            ...       ...       ...  ...            ...
# 57617         0.03     2016-11-10      0.00      0.00  ...            1.0
# 57618         0.03     2019-02-19       NaN       NaN  ...            0.0
# 57641         0.02     2018-09-04       NaN       NaN  ...            0.0
# 57671         0.02     2017-10-24       NaN       NaN  ...            0.0
# 57765         0.00     2012-10-23       NaN       NaN  ...            2.0
#
#        negative_users  user_score                              Title  \
# 3                 NaN        82.0                 Grand Theft Auto V
# 5                69.0        83.0                 Grand Theft Auto V
# 6                 NaN        90.0      Grand Theft Auto: San Andreas
# 7                68.0        79.0         Uncharted 4: A Thief's End
# 8                 NaN        87.0        Grand Theft Auto: Vice City
# ...               ...         ...                                ...
# 57617             1.0        75.0                                NaN
# 57618             0.0        73.0                                NaN
# 57641             0.0        73.0                                NaN
# 57671             0.0        78.0                                NaN
# 57765             2.0        88.0  Zero Escape: Virtue's Last Reward
#
#            Publisher                                      Genre Platform  \
# 3      RockstarNorth  Modern;Action Adventure;Modern;Open-World      PS3
# 5      RockstarNorth         Action Adventure;Modern;Open-World      PS4
# 6      RockstarNorth                    Action Adventure;Modern      PS2
# 7         NaughtyDog     General;Modern;Action Adventure;Linear      PS4
# 8      RockstarNorth                    Action Adventure;Modern      PS2
# ...              ...                                        ...      ...
# 57617            NaN                                        NaN      NaN
# 57618            NaN                                        NaN      NaN
# 57641            NaN                                        NaN      NaN
# 57671            NaN                                        NaN      NaN
# 57765       ChunSoft     Adventure;General;General;Visual Novel      PSV
#
#        Metascore  Avg_Userscore             No_Players
# 3           97.0           83.0              Up to 16
# 5           97.0           83.0              Up to 30
# 6           95.0           90.0                   1-2
# 7           93.0           83.0              Up to 10
# 8           95.0           88.0               1 Player
# ...          ...            ...                    ...
# 57617        NaN            NaN                    NaN
# 57618        NaN            NaN  No Online Multiplayer
# 57641        NaN            NaN  No Online Multiplayer
# 57671        NaN            NaN  No Online Multiplayer
# 57765       84.0           88.0  No Online Multiplayer
#
# [9026 rows x 31 columns]

# %%
group = vg_df.groupby(['genre_x'])
group.agg(['mean', 'std', 'count'])['critic_score']
# Out:
#                        mean        std  count
# genre_x
# Action            66.569075  14.832802   1578
# Action-Adventure  73.180791  12.236824    177
# Adventure         69.071174  14.234924    562
# Board Game        53.000000        NaN      1
# Education         75.000000        NaN      1
# Fighting          71.087500  13.985552    480
# MMO               80.583333   9.672537     24
# Misc              66.996109  14.987584    514
# Music             76.603448   8.100118     58
# Party             60.600000  10.788883     15
# Platform          69.813333  13.462065    600
# Puzzle            70.842640  12.500229    197
# Racing            69.357520  14.142328    758
# Role-Playing      73.311111  11.925907    945
# Sandbox           92.000000        NaN      1
# Shooter           70.787293  15.051490   1086
# Simulation        69.453659  13.586958    410
# Sports            73.479373  13.594168   1212
# Strategy          73.524173  12.080937    393
# Visual Novel      74.285714   9.754120     14

# %%
vg_df = vg_df[~vg_df.genre_x.str.contains('Board Game|Education|MMO|Party|Sandbox|Visual Novel')]

# %%
group = vg_df.groupby(['genre_x'])
group.agg(['mean', 'std', 'count'])['critic_score']
# Out:
#                        mean        std  count
# genre_x
# Action            66.569075  14.832802   1578
# Action-Adventure  73.180791  12.236824    177
# Adventure         69.071174  14.234924    562
# Fighting          71.087500  13.985552    480
# Misc              66.996109  14.987584    514
# Music             76.603448   8.100118     58
# Platform          69.813333  13.462065    600
# Puzzle            70.842640  12.500229    197
# Racing            69.357520  14.142328    758
# Role-Playing      73.311111  11.925907    945
# Shooter           70.787293  15.051490   1086
# Simulation        69.453659  13.586958    410
# Sports            73.479373  13.594168   1212
# Strategy          73.524173  12.080937    393

# %%
vg_df.loc[vg_df['critic_score'] == vg_df['critic_score'].min()]
# Out:
#                                        title console       genre_x  \
# 2272                         Kabuki Warriors      XB        Action
# 37603  Risen 3: Titan Lords Enhanced Edition     PS4  Role-Playing
#
#                  publisher    developer_x  critic_score  total_sales  \
# 2272   Crave Entertainment   Light Weight          10.0         0.06
# 37603          Deep Silver  Piranha Bytes          10.0         0.07
#
#       release_date_x  NA_Sales  EU_Sales  ...  neutral_users  negative_users  \
# 2272      2001-11-19      0.05      0.01  ...            NaN             NaN
# 37603     2015-08-21       NaN       NaN  ...            NaN             NaN
#
#        user_score  Title  Publisher Genre Platform  Metascore  Avg_Userscore  \
# 2272         25.0    NaN        NaN   NaN      NaN        NaN            NaN
# 37603         NaN    NaN        NaN   NaN      NaN        NaN            NaN
#
#        No_Players
# 2272          NaN
# 37603         NaN
#
# [2 rows x 31 columns]

# %%
# group_pub = vg_df.groupby(['publisher'])
# group_pub.agg(['count'])['title']
#vg_df[vg_df['title'].count() > 3].groupby('publisher')['title'].count()


vg_df.publisher.value_counts().reset_index(name="count").query("count > 28")["index"]
# Out:
# 0                            Electronic Arts
# 1                                    Ubisoft
# 2                                 Activision
# 3                                  EA Sports
# 4                                       Sega
# 5                                        THQ
# 6                                   Nintendo
# 7                Sony Computer Entertainment
# 8                                     Capcom
# 9                                     Konami
# 10                                     Atari
# 11                               Square Enix
# 12                                     Atlus
# 13                              Midway Games
# 14                         Eidos Interactive
# 15                                 2K Sports
# 16                              Namco Bandai
# 17                               Codemasters
# 18                                 LucasArts
# 19                                     Namco
# 20                                  2K Games
# 21                     Acclaim Entertainment
# 22    Warner Bros. Interactive Entertainment
# 23                        Namco Bandai Games
# 24                               NIS America
# 25                    Microsoft Game Studios
# 26                                   Majesco
# 27                Disney Interactive Studios
# 28                                Tecmo Koei
# 29                            Rockstar Games
# 30                        Bethesda Softworks
# 31                  Warner Bros. Interactive
# 32                               Deep Silver
# 33                                      KOEI
# 34                               Xseed Games
# 35                                  VU Games
# 36                      Sierra Entertainment
# 37                                 505 Games
# 38              Konami Digital Entertainment
# 39                       Crave Entertainment
# 40                               Aksys Games
# 41                              D3 Publisher
# 42                             EA Sports BIG
# 43                    Focus Home Interactive
# 44                         Microsoft Studios
# 45                                   Natsume
# 46                                    Bandai
# 47                                    Agetec
# 48                                     Tecmo
# 49                                   Unknown
# 50                                 Microsoft
# 51                     SouthPeak Interactive
# 52            Sony Interactive Entertainment
# 53                       Paradox Interactive
# 54                                THQ Nordic
# Name: index, dtype: object

# %% [markdown]
# Here I made a list of publishers which I edited outside of jupyter to link publishers with the public company.

# %%
pubs = np.sort(vg_df['publisher'].unique())

# pubs.to_csv('pubs.csv', index=False) 

# np.savetxt("pubs.csv", pubs, delimiter = ",")

pd.DataFrame(pubs).to_csv("pubs.csv")

# %%
vg_comp_stock = pd.read_csv(r'Data/pubs_STOCKS.csv')
vg_stk = vg_comp_stock.copy()


vg_stk.rename(columns=({"0": 'publisher', "Unnamed: 2": 'company', "Unnamed: 3": 'stock'}), inplace=True)


vg_stk = vg_stk.dropna(subset=['stock'])

vg_stk = vg_stk.drop(columns=['Unnamed: 0'])

vg_stk
# Out:
#                                publisher                      company  \
# 2                               2K Games         Take Two Interactive
# 3                                2K Play         Take Two Interactive
# 4                              2K Sports         Take Two Interactive
# 18                               Acquire  GungHo Online Entertainment
# 19                            Activision          Activision Blizzard
# 20                      Activision Value          Activision Blizzard
# 28                                 Aspyr               Embracer Group
# 32                                 Atlus                         Sega
# 36                                Bandai                 Bandai Namco
# 37            Bandai Namco Entertainment                 Bandai Namco
# 38                    Bandai Namco Games                 Bandai Namco
# 45                Blizzard Entertainment          Activision Blizzard
# 49                                Capcom                       Capcom
# 56                      Crystal Dynamics                  Square Enix
# 57                          D3 Publisher                 Bandai Namco
# 58                           D3Publisher                 Bandai Namco
# 73                             EA Sports                           EA
# 74                         EA Sports BIG                           EA
# 78                     Eidos Interactive                  Square Enix
# 79                 Eidos Interactive Ltd                  Square Enix
# 80                       Electronic Arts                           EA
# 145                                 KOEI                         KOEI
# 152                           Koei Tecmo                         KOEI
# 153                               Konami                       Konami
# 154         Konami Digital Entertainment                       Konami
# 172                                Maxis                           EA
# 178                            Microsoft                    Microsoft
# 179               Microsoft Game Studios                    Microsoft
# 180                    Microsoft Studios                    Microsoft
# 190                               NCSoft                       NCSoft
# 193                                Namco                 Bandai Namco
# 194                         Namco Bandai                 Bandai Namco
# 195                   Namco Bandai Games                 Bandai Namco
# 202                             Nintendo                     Nintendo
# 230                         PopCap Games                           EA
# 234                                 Rare                    Microsoft
# 246                       Rockstar Games         Take Two Interactive
# 250                                  SNK                          SNK
# 251                         SNK Playmore                          SNK
# 257                                 Sega                         Sega
# 266          Sony Computer Entertainment                         Sony
# 267  Sony Computer Entertainment America                         Sony
# 268   Sony Computer Entertainment Europe                         Sony
# 269       Sony Interactive Entertainment                         Sony
# 270            Sony Online Entertainment                         Sony
# 273                               Square                  Square Enix
# 274                            Square EA                  Square Enix
# 275                          Square Enix                  Square Enix
# 286                                Taito                  Square Enix
# 287                 Take-Two Interactive         Take Two Interactive
# 293                                Tecmo                        Tecmo
# 297                The Adventure Company               Embracer Group
# 314                              Ubisoft                      Ubisoft
#
#            stock
# 2           TTWO
# 3           TTWO
# 4           TTWO
# 18        3765.T
# 19          ATVI
# 20          ATVI
# 28   EMBRAC-B.ST
# 32         SGAMY
# 36        7832.T
# 37        7832.T
# 38        7832.T
# 45          ATVI
# 49         CCOEF
# 56         SQNXF
# 57        7832.T
# 58        7832.T
# 73            EA
# 74            EA
# 78         SQNXF
# 79         SQNXF
# 80            EA
# 145       3635.T
# 152       3635.T
# 153       9766.T
# 154       9766.T
# 172           EA
# 178         MSFT
# 179         MSFT
# 180         MSFT
# 190    036570.KS
# 193       7832.T
# 194       7832.T
# 195       7832.T
# 202        NTDOY
# 230           EA
# 234         MSFT
# 246         TTWO
# 250    950180.KS
# 251    950180.KS
# 257       6460.T
# 266         SONY
# 267         SONY
# 268         SONY
# 269         SONY
# 270         SONY
# 273        SQNXF
# 274        SQNXF
# 275        SQNXF
# 286        SQNXF
# 287         TTWO
# 293       3635.T
# 297  EMBRAC-B.ST
# 314        UBSFY

# %%
left = vg_df.set_index("publisher")
right = vg_stk.set_index("publisher")
vg_test = vg_df.join(vg_stk, lsuffix="_l", rsuffix="_r")
vg_test = vg_df.merge(vg_stk, how='left', on='publisher')

# %%
vg_test2 = vg_test.dropna(subset=['total_sales'])
vg_test2 = vg_test.dropna(subset=['critic_score'])
vg_test2 = vg_test.dropna(subset=['stock'])
vg_test2 = vg_test.dropna(subset=['User_Count'])

# %%
vg_main = vg_test2.dropna(subset=['stock'])

# %% [markdown]
# Removing any row that has an NA in a column.

# %%
vg_main = vg_main.dropna(subset=['release_date_x'])

# %%
vg_main.tail()
# Out:
#                              title console   genre_x  \
# 8910                 Drone Tactics      DS  Strategy
# 8912          Impossible Creatures      PC  Strategy
# 8919                   BattleForge      PC  Strategy
# 8920        Battlestations: Midway      PC  Strategy
# 8921  The Eye of Judgment: Legends     PSP  Strategy
#
#                         publisher       developer_x  critic_score  \
# 8910                        Atlus           Success          74.0
# 8912       Microsoft Game Studios             Relic          72.0
# 8919              Electronic Arts       EA Phenomic          75.0
# 8920            Eidos Interactive     Eidos Hungary          77.0
# 8921  Sony Computer Entertainment  SCE Japan Studio          69.0
#
#       total_sales release_date_x  NA_Sales  EU_Sales  ...  user_score  Title  \
# 8910         0.02     2008-05-12      0.01      0.00  ...        74.0    NaN
# 8912         0.01     2002-12-29      0.00      0.01  ...        80.0    NaN
# 8919         0.01     2009-03-24      0.00      0.01  ...        70.0    NaN
# 8920         0.01     2007-01-30      0.00      0.01  ...        73.0    NaN
# 8921         0.01     2010-03-10      0.00      0.00  ...        79.0    NaN
#
#       Publisher  Genre  Platform Metascore Avg_Userscore  No_Players  \
# 8910        NaN    NaN       NaN       NaN           NaN         NaN
# 8912        NaN    NaN       NaN       NaN           NaN         NaN
# 8919        NaN    NaN       NaN       NaN           NaN         NaN
# 8920        NaN    NaN       NaN       NaN           NaN         NaN
# 8921        NaN    NaN       NaN       NaN           NaN         NaN
#
#           company  stock
# 8910         Sega  SGAMY
# 8912    Microsoft   MSFT
# 8919           EA     EA
# 8920  Square Enix  SQNXF
# 8921         Sony   SONY
#
# [5 rows x 33 columns]

# %% [markdown]
# removing some doubled columns. Getting rid of the ones with lots of nulls

# %%
#vg_main = vg_main.drop(columns=['Title', 'Publisher' ,'Genre', 'Platform', 'Metascore', 'Avg_Userscore', 'number_players
vg_main = vg_main.drop(columns=['number_players'])
vg_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4482 entries, 0 to 8921
# Data columns (total 32 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             4482 non-null   object
#  1   console           4482 non-null   object
#  2   genre_x           4482 non-null   object
#  3   publisher         4482 non-null   object
#  4   developer_x       4482 non-null   object
#  5   critic_score      4482 non-null   float64
#  6   total_sales       4482 non-null   float64
#  7   release_date_x    4482 non-null   object
#  8   NA_Sales          4482 non-null   float64
#  9   EU_Sales          4482 non-null   float64
#  10  JP_Sales          4482 non-null   float64
#  11  Other_Sales       4482 non-null   float64
#  12  Global_Sales      4482 non-null   float64
#  13  Critic_Count      4446 non-null   float64
#  14  User_Count        4482 non-null   float64
#  15  Rating            4464 non-null   object
#  16  positive_critics  513 non-null    float64
#  17  neutral_critics   513 non-null    float64
#  18  negative_critics  513 non-null    float64
#  19  positive_users    513 non-null    float64
#  20  neutral_users     513 non-null    float64
#  21  negative_users    513 non-null    float64
#  22  user_score        4482 non-null   float64
#  23  Title             1715 non-null   object
#  24  Publisher         1715 non-null   object
#  25  Genre             1715 non-null   object
#  26  Platform          1715 non-null   object
#  27  Metascore         1715 non-null   float64
#  28  Avg_Userscore     1715 non-null   float64
#  29  No_Players        1840 non-null   object
#  30  company           4482 non-null   object
#  31  stock             4482 non-null   object
# dtypes: float64(18), object(14)
# memory usage: 1.1+ MB

# %%
# test = vg_main.dropna(thresh=len(vg_main), axis=1)

# for col in test.columns:
#     print(col, test[col].isna().sum())
    
# len(test)
# Out:
# title 0
# console 0
# genre_x 0
# publisher 0
# developer_x 0
# critic_score 0
# total_sales 0
# release_date_x 0
# NA_Sales 0
# EU_Sales 0
# JP_Sales 0
# Other_Sales 0
# Global_Sales 0
# User_Count 0
# user_score 0
# 6880

# %%
keep_comps = vg_main.company.value_counts().reset_index(name="count").query("count > 20")#["index"]

# %%
test2 = vg_main[~vg_main['company'].isin(keep_comps)]

# %%
comp_30 = test2.company.value_counts().reset_index(name="count").query("count > 30")["index"]
test3 = test2[test2['company'].isin(comp_30)]

# %%
test3
# Out:
#                               title console   genre_x  \
# 0                Grand Theft Auto V     PS3    Action
# 1                Grand Theft Auto V     PS4    Action
# 2     Grand Theft Auto: San Andreas     PS2    Action
# 3        Uncharted 4: A Thief's End     PS4    Action
# 4       Grand Theft Auto: Vice City     PS2    Action
# ...                             ...     ...       ...
# 8910                  Drone Tactics      DS  Strategy
# 8912           Impossible Creatures      PC  Strategy
# 8919                    BattleForge      PC  Strategy
# 8920         Battlestations: Midway      PC  Strategy
# 8921   The Eye of Judgment: Legends     PSP  Strategy
#
#                            publisher       developer_x  critic_score  \
# 0                     Rockstar Games    Rockstar North          94.0
# 1                     Rockstar Games    Rockstar North          97.0
# 2                     Rockstar Games    Rockstar North          95.0
# 3     Sony Interactive Entertainment       Naughty Dog          92.0
# 4                     Rockstar Games    Rockstar North          96.0
# ...                              ...               ...           ...
# 8910                           Atlus           Success          74.0
# 8912          Microsoft Game Studios             Relic          72.0
# 8919                 Electronic Arts       EA Phenomic          75.0
# 8920               Eidos Interactive     Eidos Hungary          77.0
# 8921     Sony Computer Entertainment  SCE Japan Studio          69.0
#
#       total_sales release_date_x  NA_Sales  EU_Sales  ...  user_score  \
# 0           20.32     2013-09-17      7.02      9.09  ...        82.0
# 1           19.39     2014-11-18      3.96      6.31  ...        83.0
# 2           20.81     2004-10-26      9.43      0.40  ...        90.0
# 3            5.38     2016-05-10      1.85      2.50  ...        79.0
# 4           16.15     2002-10-28      8.41      5.49  ...        87.0
# ...           ...            ...       ...       ...  ...         ...
# 8910         0.02     2008-05-12      0.01      0.00  ...        74.0
# 8912         0.01     2002-12-29      0.00      0.01  ...        80.0
# 8919         0.01     2009-03-24      0.00      0.01  ...        70.0
# 8920         0.01     2007-01-30      0.00      0.01  ...        73.0
# 8921         0.01     2010-03-10      0.00      0.00  ...        79.0
#
#                               Title      Publisher  \
# 0                Grand Theft Auto V  RockstarNorth
# 1                Grand Theft Auto V  RockstarNorth
# 2     Grand Theft Auto: San Andreas  RockstarNorth
# 3        Uncharted 4: A Thief's End     NaughtyDog
# 4       Grand Theft Auto: Vice City  RockstarNorth
# ...                             ...            ...
# 8910                            NaN            NaN
# 8912                            NaN            NaN
# 8919                            NaN            NaN
# 8920                            NaN            NaN
# 8921                            NaN            NaN
#
#                                           Genre  Platform Metascore  \
# 0     Modern;Action Adventure;Modern;Open-World       PS3      97.0
# 1            Action Adventure;Modern;Open-World       PS4      97.0
# 2                       Action Adventure;Modern       PS2      95.0
# 3        General;Modern;Action Adventure;Linear       PS4      93.0
# 4                       Action Adventure;Modern       PS2      95.0
# ...                                         ...       ...       ...
# 8910                                        NaN       NaN       NaN
# 8912                                        NaN       NaN       NaN
# 8919                                        NaN       NaN       NaN
# 8920                                        NaN       NaN       NaN
# 8921                                        NaN       NaN       NaN
#
#       Avg_Userscore  No_Players               company  stock
# 0              83.0   Up to 16   Take Two Interactive   TTWO
# 1              83.0   Up to 30   Take Two Interactive   TTWO
# 2              90.0        1-2   Take Two Interactive   TTWO
# 3              83.0   Up to 10                   Sony   SONY
# 4              88.0    1 Player  Take Two Interactive   TTWO
# ...             ...         ...                   ...    ...
# 8910            NaN         NaN                  Sega  SGAMY
# 8912            NaN         NaN             Microsoft   MSFT
# 8919            NaN         NaN                    EA     EA
# 8920            NaN         NaN           Square Enix  SQNXF
# 8921            NaN         NaN                  Sony   SONY
#
# [4440 rows x 32 columns]

# %%
test3['company'].unique()
# Out:
# array(['Take Two Interactive', 'Sony', 'Konami', 'Ubisoft', 'Square Enix',
#        'Capcom', 'EA', 'Activision Blizzard', 'Nintendo', 'Microsoft',
#        'Bandai Namco', 'KOEI', 'Sega', 'Tecmo'], dtype=object)

# %%
test3.to_csv('Data/vg_complete_df.csv', index=False)

# %%
# test2 = test.drop(thresh=len(vg_main), axis=1)

# for col in test.columns:
     print(col, test[col].isna().sum())
    
len(test)   


# group = test.groupby(['company'])
# group.agg(['mean', 'count'])['critic_score']
# Out:
#   File "<ipython-input-269-65e2adca6baf>", line 4
#     print(col, test[col].isna().sum())
#     ^
# IndentationError: unexpected indent

# %%
group = vg_test2.groupby(['company', 'genre_x'])
group.agg(['mean', 'count'])['critic_score']
# Out:
#                                            mean  count
# company             genre_x
# Activision Blizzard Action            64.355372    121
#                     Action-Adventure  67.000000      6
#                     Adventure         55.000000      1
#                     Fighting          70.600000      5
#                     Misc              73.288462     52
# ...                                         ...    ...
# Ubisoft             Role-Playing      69.388889     18
#                     Shooter           72.098765     81
#                     Simulation        68.064516     31
#                     Sports            57.074074     27
#                     Strategy          69.111111     18
#
# [188 rows x 2 columns]

# %%
print(len(vg_test))
print(vg_test['stock'].isna().sum())
print(vg_test['User_Count'].isna().sum())
# Out:
# 8970
# 3356
# 2079

# %% [markdown]
# No clue what I was doing here. Got to redo some stuff.

# %%
# transforms = [dict(
#     type = 'groupby',
#     groups = 'genre_x',
# #     styles = [
# #         dict(target = 'Moe', value = dict(marker = dict(color = 'blue'))),
# #         dict(target = 'Larry', value = dict(marker = dict(color = 'red'))),
# #         dict(target = 'Curly', value = dict(marker = dict(color = 'black')))
# #     ]
#   )]


fig = px.scatter(group, x='critic_score', y='user_score', hover_data=['title']
               , transforms = [dict(
    type = 'groupby',
    groups = 'genre_x',
#     styles = [
#         dict(target = 'Moe', value = dict(marker = dict(color = 'blue'))),
#         dict(target = 'Larry', value = dict(marker = dict(color = 'red'))),
#         dict(target = 'Curly', value = dict(marker = dict(color = 'black')))
#     ]
  )] )
fig.show()
# Out:
# ------------------------------------------------------------------
# TypeError                        Traceback (most recent call last)
# <ipython-input-211-742b318360a7> in <module>
#      10
#      11
# ---> 12 fig = px.scatter(group, x='critic_score', y='user_score', hover_data=['title']
#      13                , transforms = [dict(
#      14     type = 'groupby',
#
# TypeError: scatter() got an unexpected keyword argument 'transforms'

# %%
comp_30 = vg_main.company.value_counts().reset_index(name="count").query("count > 30")["index"]
# Out:
# 0                       EA
# 1      Activision Blizzard
# 2                  Ubisoft
# 3                     Sega
# 4             Bandai Namco
# 5                     Sony
# 6     Take Two Interactive
# 7                 Nintendo
# 8              Square Enix
# 9                   Konami
# 10                  Capcom
# 11               Microsoft
# 12                    KOEI
# 13                   Tecmo
# Name: index, dtype: object
